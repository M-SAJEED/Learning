# %%
import pandas as pd

# %%
df=pd.read_csv('new.csv')

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df
# Out:
#     eno    ename  salary  deptno         doj
# 0    10    Amber    1000      10  2018-05-14
# 1     2     Amar    1000      10  2017-03-22
# 2     8    Sagar    1000      20  2020-11-30
# 3     4   Thomas    1000      10  2019-08-18
# 4     5     Jade    2000      10  2021-02-10
# 5     6    Smith    1000      10  2016-12-01
# 6     7   Robert    3000      20  2023-06-25
# 7     3     Nick    1000      30  2015-09-15
# 8     9    Naman    4000      30  2020-01-20
# 9     1    Vikas    1000      30  2017-10-03
# 10   11   Dennis   41000      30  2024-01-05
# 11   12    Karan    2200      20  2018-06-16
# 12   13   Simran    1500      10  2019-12-19
# 13   14     Amit    2000      30  2022-04-09
# 14   15     Neha    1700      20  2021-07-22
# 15   16    Rahul    1200      10  2016-03-28
# 16   17    Divya    3000      30  2015-11-11
# 17   18   Rakesh    1800      10  2020-09-04
# 18   19   Monica    2500      20  2023-08-07
# 19   20     John    2300      30  2018-10-29
# ...

# %%
type(df[['eno','salary']])
# Out:
# pandas.DataFrame

# %%
df[['eno','salary']]
# Out:
#     eno  salary
# 0    10    1000
# 1     2    1000
# 2     8    1000
# 3     4    1000
# 4     5    2000
# 5     6    1000
# 6     7    3000
# 7     3    1000
# 8     9    4000
# 9     1    1000
# 10   11   41000
# 11   12    2200
# 12   13    1500
# 13   14    2000
# 14   15    1700
# 15   16    1200
# 16   17    3000
# 17   18    1800
# 18   19    2500
# 19   20    2300
# 20   21    2700
# 21   22    1000
# 22   23    1500
# 23   24    1800
# 24   25    2000
# 25   26    1600
# 26   27    1400
# 27   28    1300
# 28   29    1200
# 29   30    1100
# 30   31    1900
# 31   32    2100
# 32   33    2400
# 33   34    2000
# 34   35    3000
# 35   36    3200
# 36   37    2800
# 37   38    2700
# 38   39    2600
# 39   40    2500
# 40   41    2300
# 41   42    2200
# 42   43    2100
# 43   44    1900
# 44   45    1800
# 45   46    1700
# 46   47    1600

# %%
df.head()
# Out:
#    eno   ename  salary  deptno         doj
# 0   10   Amber    1000      10  2018-05-14
# 1    2    Amar    1000      10  2017-03-22
# 2    8   Sagar    1000      20  2020-11-30
# 3    4  Thomas    1000      10  2019-08-18
# 4    5    Jade    2000      10  2021-02-10

# %%
df.tail()
# Out:
#     eno    ename  salary  deptno         doj
# 42   43    Geeta    2100      30  2017-11-14
# 43   44    Ashok    1900      10  2016-06-08
# 44   45  Sanjana    1800      20  2023-03-17
# 45   46    Manoj    1700      30  2019-07-24
# 46   47    Payal    1600      20  2015-10-10

# %%
df1 = pd.read_csv('new.csv')

# %%
df1.head()
# Out:
#    eno   ename  salary  deptno         doj
# 0   10   Amber    1000      10  2018-05-14
# 1    2    Amar    1000      10  2017-03-22
# 2    8   Sagar    1000      20  2020-11-30
# 3    4  Thomas   10000      10  2019-08-18
# 4    5    Jade    2000      10  2021-02-10

# %%
df1.iloc[3:12]
# Out:
#     eno   ename  salary  deptno         doj
# 3     4  Thomas   10000      10  2019-08-18
# 4     5    Jade    2000      10  2021-02-10
# 5     6   Smith    1000      10  2016-12-01
# 6     7  Robert    3000      20  2023-06-25
# 7     3    Nick    1000      30  2015-09-15
# 8     9   Naman    4000      30  2020-01-20
# 9     1   Vikas    1000      30  2017-10-03
# 10   11  Dennis   41000      30  2024-01-05
# 11   12   Karan    2200      20  2018-06-16

# %%
# Out:
#     eno    ename
# 0    10    Amber
# 1     2     Amar
# 2     8    Sagar
# 3     4   Thomas
# 4     5     Jade
# 5     6    Smith
# 6     7   Robert
# 7     3     Nick
# 8     9    Naman
# 9     1    Vikas
# 10   11   Dennis
# 11   12    Karan
# 12   13   Simran
# 13   14     Amit
# 14   15     Neha
# 15   16    Rahul
# 16   17    Divya
# 17   18   Rakesh
# 18   19   Monica
# 19   20     John
# 20   21    Sneha
# 21   22    David
# 22   23    Anita
# 23   24    Vinod
# 24   25    Meena
# 25   26    Harsh
# 26   27   Kavita
# 27   28    Mohan
# 28   29    Priya
# 29   30   Suresh
# 30   31     Rani
# 31   32     Ajay
# 32   33    Nidhi
# 33   34    Vivek
# 34   35    Seema
# 35   36     Ritu
# 36   37    Kunal
# 37   38     Alok
# 38   39   Poonam
# 39   40     Yash
# 40   41     Nina
# 41   42    Tarun
# 42   43    Geeta
# 43   44    Ashok
# 44   45  Sanjana
# 45   46    Manoj
# 46   47    Payal

# %%
df.dtypes
# Out:
# eno       int64
# ename       str
# salary    int64
# deptno    int64
# doj         str
# dtype: object

# %%
df1 = pd.read_csv('new.csv',parse_dates=['doj'])

# %%
df1.dtypes
# Out:
# eno                int64
# ename                str
# salary             int64
# deptno             int64
# doj       datetime64[us]
# dtype: object

# %%
df1['doj'].dt.quarter.head()
# Out:
# 0    2
# 1    1
# 2    4
# 3    3
# 4    1
# Name: doj, dtype: int32
